# %%
import geopandas as gpd 
import pandas as pd, requests, json
map = gpd.read_file("geojson_files/c2030_10CFEPpolys.json")
map.plot()
# Out:
# <Axes: >

# %%
import plotly.express as px

map.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
df = pd.read_csv("geojson_files/cultural_points.csv")

from geopandas import GeoDataFrame
from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(df.Longitude, df.Latitude)]
df = df.drop(['Longitude', 'Latitude'], axis=1)
gdf = GeoDataFrame(df, crs="EPSG:4326", geometry=geometry)

df.plot()
# Out:
# <Axes: >

# %%
# Load a map with data and config and height
from keplergl import KeplerGl
map_2 = KeplerGl(height=400, data={"data_1": df})
map_2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Load a map with data and config and height
# ----> 2 from keplergl import KeplerGl
#       3 map_2 = KeplerGl(height=400, data={"data_1": df})
#       4 map_2
#
# ModuleNotFoundError: No module named 'keplergl'
